# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
import xgboost
from xgboost import XGBClassifier
from mlxtend.preprocessing import minmax_scaling

# %%
diabetes=pd.read_csv('diabetes.csv')
diabetes
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [768 rows x 9 columns]

# %%
print(len(diabetes[diabetes['Outcome']==1]))
print(len(diabetes[diabetes['Outcome']==0]))
# Out:
# 268
# 500

# %%
print(diabetes[0:1])
# Out:
#    Pregnancies  Glucose  BloodPressure  ...  DiabetesPedigreeFunction  Age  Outcome
# 0            6      148             72  ...                     0.627   50        1
#
# [1 rows x 9 columns]

# %%
data=pd.read_csv('diabetes.csv')
del data['Outcome']
X=data
Y=diabetes['Outcome']
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.3)

# %%
list1=np.arange(10,1000,10)
scores=[]
for k in list1:
  model=RandomForestClassifier(n_estimators=k)
  model.fit(x_train,y_train)
  scores.append(model.score(x_test,y_test))

optimal_k=list1[scores.index(max(scores))]
print(optimal_k)
# Out:
# 50

# %%
best_model=RandomForestClassifier(n_estimators=optimal_k)
best_model.fit(x_train,y_train)
best_model.score(x_test,y_test)
# Out:
# 0.7619047619047619

# %%
joblib.dump(best_model,'diabetes_model.pkl')
# Out:
# ['diabetes_model.pkl']

# %%
estimator = XGBClassifier(max_depth=1)
params={
    'n_estimators': range(50, 400, 40),
    'learning_rate': [0.1, 0.5, 0.01, 0.05]
}

grid_search = GridSearchCV(
    estimator=estimator,
    param_grid=params,
    scoring = 'roc_auc',
    cv = 10,
    verbose=True
)

grid_search.fit(x_train,y_train)
# Out:
# Fitting 10 folds for each of 36 candidates, totalling 360 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 360 out of 360 | elapsed:   14.8s finished
# GridSearchCV(cv=10, error_score=nan,
#              estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                      colsample_bylevel=1, colsample_bynode=1,
#                                      colsample_bytree=1, gamma=0,
#                                      learning_rate=0.1, max_delta_step=0,
#                                      max_depth=1, min_child_weight=1,
#                                      missing=None, n_estimators=100, n_jobs=1,
#                                      nthread=None, objective='binary:logistic',
#                                      random_state=0, reg_alpha=0, reg_lambda=1,
#                                      scale_pos_weight=1, seed=None, silent=None,
# ...

# %%
print(grid_search.best_estimator_)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=1,
#               min_child_weight=1, missing=None, n_estimators=250, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
best_model=grid_search.best_estimator_
best_model.fit(x_train,y_train)
best_model.score(x_test,y_test)
# Out:
# 0.7662337662337663

# %%
best_model.fit(X,Y)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=1,
#               min_child_weight=1, missing=None, n_estimators=250, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
import pickle
from sklearn.externals import joblib

joblib.dump(best_model,'diabetes.pkl')
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
scaled_data = minmax_scaling(diabetes,columns=['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age'])

# %%
import tensorflow as tf
from keras.layers import Input, Lambda,LSTM, Dense, Flatten,Conv2D,MaxPooling2D,Dropout,Flatten,BatchNormalization
from keras.models import Model,Sequential

# %%
input_dim = x_train.shape[1]
model = Sequential()
model.add(Input(shape=(input_dim,)))
model.add(Dense(8,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
print(model.summary())

optimizer = tf.keras.optimizers.RMSprop(0.01)
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_32 (Dense)             (None, 8)                 72
# _________________________________________________________________
# dense_33 (Dense)             (None, 4)                 36
# _________________________________________________________________
# dense_34 (Dense)             (None, 1)                 5
# ...
# Total params: 113
# Trainable params: 113
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(optimizer=optimizer,loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(scaled_data,diabetes['Outcome'],epochs=1000,verbose=2,validation_split=0.2)
# Out:
# Epoch 1/1000
# 20/20 - 0s - loss: 4.1354e-08 - accuracy: 0.6384 - val_loss: 4.2575e-08 - val_accuracy: 0.6494
# Epoch 2/1000
# 20/20 - 0s - loss: 4.1354e-08 - accuracy: 0.6384 - val_loss: 4.2575e-08 - val_accuracy: 0.6494
# Epoch 3/1000
# 20/20 - 0s - loss: 4.1354e-08 - accuracy: 0.6384 - val_loss: 4.2575e-08 - val_accuracy: 0.6494
# Epoch 4/1000
# 20/20 - 0s - loss: 4.1354e-08 - accuracy: 0.6384 - val_loss: 4.2575e-08 - val_accuracy: 0.6494
# Epoch 5/1000
# 20/20 - 0s - loss: 4.1354e-08 - accuracy: 0.6384 - val_loss: 4.2575e-08 - val_accuracy: 0.6494
# Epoch 6/1000
# 20/20 - 0s - loss: 4.1354e-08 - accuracy: 0.6384 - val_loss: 4.2575e-08 - val_accuracy: 0.6494
# Epoch 7/1000
# 20/20 - 0s - loss: 4.1354e-08 - accuracy: 0.6384 - val_loss: 4.2575e-08 - val_accuracy: 0.6494
# Epoch 8/1000
# 20/20 - 0s - loss: 4.1354e-08 - accuracy: 0.6384 - val_loss: 4.2575e-08 - val_accuracy: 0.6494
# Epoch 9/1000
# ...
